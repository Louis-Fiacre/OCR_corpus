# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print(os.getcwd())
df = pd.read_excel('Corpus_ocr_distances.xlsx')
df
# Out:
# /home/lf/Bureau/Memoire/1_Etapes_OCR/sortie distances corpus
#             Auteurs                                 Textes  WER_Gallica  \
# 0         Léon_Bloy               lettres_à_Pierre_Termier         5.26
# 1         Léon_Bloy            Entrepreneur_de_démolitions         5.99
# 2         Léon_Bloy         Les_funérailles_du_naturalisme         0.00
# 3         Léon_Bloy                 Le_salut_par_les_juifs        12.20
# 4         Léon_Bloy              Exégèse_des_lieux_communs         4.74
# 5         Léon_Bloy  Christophe_Colomb_devant_les_taureaux         7.17
# 6         Léon_Bloy                            Je_m_accuse         8.44
# 7  Georges_Bernanos         le_chemin_de_la_croix_des_ames         0.00
# 8  Georges_Bernanos            la_france_contre_les_robots         0.00
# 9  Georges_Bernanos                  scandale_de_la_verite         0.00
#
#    WER_Tesseract  WER_Tesseract_ScanTailor  CER_Gallica  CER_Tesseract  \
# ...

# %%
df.describe()
# Out:
#        WER_Gallica  WER_Tesseract  WER_Tesseract_ScanTailor  CER_Gallica  \
# count    10.000000      10.000000                 10.000000    10.000000
# mean      4.380000       5.728000                  2.179000    11.232000
# std       4.290219       4.153119                  1.055267    14.260035
# min       0.000000       1.550000                  0.000000     0.000000
# 25%       0.000000       2.650000                  1.660000     0.000000
# 50%       5.000000       4.390000                  2.340000     5.860000
# 75%       6.875000       6.617500                  2.752500    16.022500
# max      12.200000      13.060000                  3.920000    39.520000
#
#        CER_Tesseract  CER_Tesseract_ScanTailor        JAC  JAC_Gallica  \
# count      10.000000                 10.000000  10.000000    10.000000
# mean       13.983000                  9.053000   0.026500     0.015820
# std         6.075689                  4.617811   0.008182     0.014557
# ...

# %%
df.CER_Tesseract_ScanTailor.describe()
# Out:
# count    10.000000
# mean      9.053000
# std       4.617811
# min       0.000000
# 25%       6.932500
# 50%       9.330000
# 75%      11.302500
# max      17.910000
# Name: CER_Tesseract_ScanTailor, dtype: float64

# %%
df.plot(x="Textes", y=["WER_Gallica", "WER_Tesseract", "WER_Tesseract_ScanTailor"], kind="bar")
plt.ylabel('Pourcentage')
plt.xlabel('')
plt.savefig('WER.png', format='png', facecolor='white', bbox_inches='tight')
plt.show()

# %%
df.plot(x="Textes", y=["CER_Gallica", "CER_Tesseract", "CER_Tesseract_ScanTailor"], kind="bar")
plt.ylabel('Pourcentage')
plt.xlabel('')
plt.savefig('CER.png', format='png', facecolor='white', bbox_inches='tight')
plt.show()
